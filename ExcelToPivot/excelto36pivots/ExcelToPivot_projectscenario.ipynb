# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the excel file

# %%
df=pd.read_excel('Input.xlsx')
df.head()
# Out:
#   Fiscal Quarter ID  Fiscal Period ID Sales Level 1  Sales Level 2  \
# 0            2025Q2            202504      Americas  AMERICAS_MISC
# 1            2025Q2            202504      Americas  AMERICAS_MISC
# 2            2025Q2            202504      Americas  AMERICAS_MISC
# 3            2025Q2            202504      Americas  AMERICAS_MISC
# 4            2025Q2            202504      Americas  AMERICAS_MISC
#
#              Sales Level 3 Internal Business Entity Description  \
# 0  AMERICAS MISC CONTRA L3                        Cisco Compute
# 1  AMERICAS MISC CONTRA L3                        Cisco Compute
# 2  AMERICAS MISC CONTRA L3                        Cisco Compute
# 3  AMERICAS MISC CONTRA L3                        Cisco Compute
# 4  AMERICAS MISC CONTRA L3                        Cisco Compute
#
#   Internal Sub Business Entity Description Corporate Bookings Flag  \
# 0                          Hyper Converged                       Y
# 1                          Hyper Converged                       Y
# 2                          Hyper Converged                       Y
# 3                          Hyper Converged                       Y
# 4                          Hyper Converged                       Y
#
#   Organization Code Technology Group  ... Product Classification  \
# 0                 -            CSPTG  ...               Software
# 1                 -            CSPTG  ...               Hardware
# 2                 -            CSPTG  ...               Software
# 3                 -            CSPTG  ...               Software
# 4                 -            CSPTG  ...               Software
#
#              Software Type Revenue Recognition Flag Accounting Rule  \
# 0     On-Premise Perpetual                        Y             NaN
# 1  On-Premise Subscription                        Y             NaN
# 2  On-Premise Subscription                        Y             NaN
# 3  On-Premise Subscription                        Y             NaN
# 4  On-Premise Subscription                        Y             NaN
#
#   Product Family Txn Net Price Indicator XCAT Flag     Business Model  \
# 0        HCIPPSW                       =         N  Physical Delivery
# 1          UCSHX                       =         N  Physical Delivery
# 2          HCIPS                       =         N        Non Factory
# 3          HCISW                       =         N        Non Factory
# 4           HXDP                       =         N        Non Factory
#
#   Org Category Product Bookings Net
# 0     Adj. Org               -80.06
# 1     Adj. Org            -10774.67
# 2     Adj. Org              -754.32
# 3     Adj. Org             -9439.98
# 4     Adj. Org               -38.30
#
# [5 rows x 26 columns]

# %% [markdown]
# # Check the datatype of all the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147359 entries, 0 to 147358
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Fiscal Quarter ID                         147359 non-null  object
#  1   Fiscal Period ID                          147359 non-null  int64
#  2   Sales Level 1                             147359 non-null  object
#  3   Sales Level 2                             147359 non-null  object
#  4   Sales Level 3                             147359 non-null  object
#  5   Internal Business Entity Description      147359 non-null  object
#  6   Internal Sub Business Entity Description  147359 non-null  object
#  7   Corporate Bookings Flag                   147359 non-null  object
#  8   Organization Code                         147359 non-null  object
#  9   Technology Group                          147359 non-null  object
#  10  Business Unit                             147359 non-null  object
#  11  Bookings Adjustments Type                 97553 non-null   object
#  12  Bookings Adjustments Code                 147359 non-null  object
#  13  Delivery Option Code                      147359 non-null  object
#  14  Monetization                              147359 non-null  object
#  15  Product Category                          147359 non-null  object
#  16  Product Classification                    147359 non-null  object
#  17  Software Type                             147359 non-null  object
#  18  Revenue Recognition Flag                  147359 non-null  object
#  19  Accounting Rule                           123455 non-null  object
#  20  Product Family                            147359 non-null  object
#  21  Txn Net Price Indicator                   147359 non-null  object
#  22  XCAT Flag                                 147359 non-null  object
#  23  Business Model                            147359 non-null  object
#  24  Org Category                              147359 non-null  object
#  25  Product Bookings Net                      147359 non-null  float64
# dtypes: float64(1), int64(1), object(24)
# memory usage: 29.2+ MB

# %% [markdown]
# # Check if any column has NaN value

# %%
df.isna().any()
# Out:
# Fiscal Quarter ID                           False
# Fiscal Period ID                            False
# Sales Level 1                               False
# Sales Level 2                               False
# Sales Level 3                               False
# Internal Business Entity Description        False
# Internal Sub Business Entity Description    False
# Corporate Bookings Flag                     False
# Organization Code                           False
# Technology Group                            False
# Business Unit                               False
# Bookings Adjustments Type                    True
# Bookings Adjustments Code                   False
# Delivery Option Code                        False
# Monetization                                False
# Product Category                            False
# Product Classification                      False
# Software Type                               False
# Revenue Recognition Flag                    False
# Accounting Rule                              True
# Product Family                              False
# Txn Net Price Indicator                     False
# XCAT Flag                                   False
# Business Model                              False
# Org Category                                False
# Product Bookings Net                        False
# dtype: bool

# %% [markdown]
# # Checked the NaN column

# %%
df['Bookings Adjustments Type']
# Out:
# 0              BOOKING
# 1              BOOKING
# 2              BOOKING
# 3              BOOKING
# 4              BOOKING
#               ...
# 147354             NaN
# 147355             NaN
# 147356             NaN
# 147357    DSV Bookings
# 147358    DSV Bookings
# Name: Bookings Adjustments Type, Length: 147359, dtype: object

# %% [markdown]
# # to avoid warnings in the code

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Pivot table created with 1st condition

# %%
p1=pd.pivot_table(df,columns=['Fiscal Quarter ID','Fiscal Period ID'],index='Business Model',values='Product Bookings Net',aggfunc=sum)
p1
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Acquisition        3.977391e+08
# Electronic         2.208989e+07
# NON FACTORY        2.395364e+07
# Non Factory        6.446795e+08
# Physical Delivery  1.459114e+09
# Traditional MSJ    1.259692e+08
# XCAT-MSJ          -1.739578e+06

# %%
p2=pd.pivot_table(df,columns=['Fiscal Quarter ID','Fiscal Period ID'],index='Business Model',values='Product Bookings Net',aggfunc=sum)
p2
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Acquisition        3.977391e+08
# Electronic         2.208989e+07
# NON FACTORY        2.395364e+07
# Non Factory        6.446795e+08
# Physical Delivery  1.459114e+09
# Traditional MSJ    1.259692e+08
# XCAT-MSJ          -1.739578e+06

# %%
filtered_df = df[(df['Corporate Bookings Flag'] == 'Y')]
pcbf = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
pcbf
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Acquisition        3.977391e+08
# Electronic         2.009183e+07
# NON FACTORY        2.396806e+07
# Non Factory        6.507856e+08
# Physical Delivery  1.428273e+09
# Traditional MSJ    1.120785e+08
# XCAT-MSJ          -1.739578e+06

# %%
filtered_df = df[(df['Corporate Bookings Flag'] == 'Y') & (df['Bookings Adjustments Type']=='BOOKING')]
pbat = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
pbat
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Acquisition        3.977391e+08
# Electronic        -3.636784e+05
# NON FACTORY       -3.577211e+05
# Non Factory       -5.905929e+07
# Physical Delivery -1.246890e+08
# Traditional MSJ   -5.633781e+06
# XCAT-MSJ          -6.487917e+07

# %%
filtered_df =df[df['Bookings Adjustments Type']=='BOOKING']
                
p3 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p3
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Acquisition        3.977391e+08
# Electronic        -4.266263e+05
# NON FACTORY       -3.577211e+05
# Non Factory       -6.346568e+07
# Physical Delivery -3.048749e+08
# Traditional MSJ   -6.830487e+06
# XCAT-MSJ          -6.487917e+07

# %% [markdown]
# # Remove lead and trail space from the column

# %%
df['Bookings Adjustments Type'] = df['Bookings Adjustments Type'].str.strip()
df['Bookings Adjustments Type']
# Out:
# 0              BOOKING
# 1              BOOKING
# 2              BOOKING
# 3              BOOKING
# 4              BOOKING
#               ...
# 147354             NaN
# 147355             NaN
# 147356             NaN
# 147357    DSV Bookings
# 147358    DSV Bookings
# Name: Bookings Adjustments Type, Length: 147359, dtype: object

# %% [markdown]
# # Convert NaN to 0 for the specific column

# %%
df['Bookings Adjustments Type'] = df['Bookings Adjustments Type'].fillna(0)
df['Bookings Adjustments Type']
# Out:
# 0              BOOKING
# 1              BOOKING
# 2              BOOKING
# 3              BOOKING
# 4              BOOKING
#               ...
# 147354               0
# 147355               0
# 147356               0
# 147357    DSV Bookings
# 147358    DSV Bookings
# Name: Bookings Adjustments Type, Length: 147359, dtype: object

# %% [markdown]
# # Filter conditions to check the Booking Adjustment Type== 0

# %%
filtered_df =df[df['Bookings Adjustments Type']==0]
                
p3 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p3
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic         2.251651e+07
# NON FACTORY        2.431136e+07
# Non Factory        7.081452e+08
# Physical Delivery  1.763989e+09
# Traditional MSJ    1.327997e+08
# XCAT-MSJ           6.313960e+07

# %% [markdown]
# # FILTER-1 to 5

# %%
filtered_df = df[(df['Corporate Bookings Flag'] == 'Y') & (df['Bookings Adjustments Type']=='BOOKING') |
                (df['Corporate Bookings Flag'] == 'Y') & (df['Bookings Adjustments Type']==0)]
                 
p4 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p4
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Acquisition        3.977391e+08
# Electronic         1.483513e+07
# NON FACTORY        2.396795e+07
# Non Factory        4.815038e+08
# Physical Delivery  8.726054e+08
# Traditional MSJ    7.331381e+07
# XCAT-MSJ          -1.739578e+06

# %%
df['Business Model'].unique()
# Out:
# array(['Physical Delivery', 'Non Factory', 'XCAT-MSJ', 'Traditional MSJ',
#        'Electronic', 'NON FACTORY', 'Acquisition'], dtype=object)

# %% [markdown]
# # FILTER 6 to 8- 2 tier DSV LPOS WPL

# %%
df['Txn Net Price Indicator'].unique()
# Out:
# array(['=', 'Y', 'N'], dtype=object)

# %%
c1=['DSV Bookings',0] # list created with conditions for df['Bookings Adjustments Type']

filtered_df = df[(df['Corporate Bookings Flag'] == 'Y') & (df['Bookings Adjustments Type'].isin(c1)) & (df['Txn Net Price Indicator']=='N')] 

p5 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p5
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Non Factory        13129.363815
# Physical Delivery  12013.800000

# %% [markdown]
# # FILTER-2tierposnet

# %%
c1=['DSV Bookings',0] # list created with conditions for df['Bookings Adjustments Type']

filtered_df = df[(df['Corporate Bookings Flag'] == 'Y') & (df['Bookings Adjustments Type'].isin(c1)) & (df['Txn Net Price Indicator']=='Y')] 

p6 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p6
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic         5.281116e+06
# NON FACTORY        1.041000e+02
# Non Factory        2.416523e+08
# Physical Delivery  3.069339e+08
# Traditional MSJ    3.905091e+07

# %% [markdown]
# # FILTER-stdfctrnet

# %%
filtered_df = df[(df['Corporate Bookings Flag'] == 'Y') & (df['Bookings Adjustments Type']=='BOOKING')]
p7 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p7
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Acquisition        3.977391e+08
# Electronic        -3.636784e+05
# NON FACTORY       -3.577211e+05
# Non Factory       -5.905929e+07
# Physical Delivery -1.246890e+08
# Traditional MSJ   -5.633781e+06
# XCAT-MSJ          -6.487917e+07

# %% [markdown]
# # FILTER-stdfacgrosbkg

# %%
filtered_df = df[(df['Corporate Bookings Flag'] == 'Y') & (df['Bookings Adjustments Type']==0)]
p8 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p8
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic         1.519881e+07
# NON FACTORY        2.432568e+07
# Non Factory        5.405631e+08
# Physical Delivery  9.972944e+08
# Traditional MSJ    7.894759e+07
# XCAT-MSJ           6.313960e+07

# %% [markdown]
# # FILTER-stdnonfacgros

# %%
c1=['BOOKING',0] # list created with conditions for df['Bookings Adjustments Type']

filtered_df = df[(df['Corporate Bookings Flag'] == 'Y') & (df['Bookings Adjustments Type'].isin(c1))] 

p9 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p9
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Acquisition        3.977391e+08
# Electronic         1.483513e+07
# NON FACTORY        2.396795e+07
# Non Factory        4.815038e+08
# Physical Delivery  8.726054e+08
# Traditional MSJ    7.331381e+07
# XCAT-MSJ          -1.739578e+06

# %% [markdown]
# # FILTER-2tierfactorynetbookingwpl

# %%
c1=['BOOKING',0] # list created with conditions for df['Bookings Adjustments Type']
c2=['=','N'] # List created with conditions for df['Txn Net Price Indicator']

filtered_df = df[(df['Corporate Bookings Flag'] == 'N') & (df['Bookings Adjustments Type'].isin(c1)) & (df['Txn Net Price Indicator'].isin(c2))] 

p10 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p10
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic         5.235159e+05
# Non Factory        1.746822e+06
# Physical Delivery  1.626274e+08
# Traditional MSJ   -6.191227e+04

# %% [markdown]
# # FILTER-2-Tier Factory Net (net price)

# %%
c1=['BOOKING',0] # list created with conditions for df['Bookings Adjustments Type']


filtered_df = df[(df['Corporate Bookings Flag'] == 'N') & (df['Bookings Adjustments Type'].isin(c1)) & (df['Txn Net Price Indicator']=='Y')] 

p11 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p11
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic         6.731241e+06
# NON FACTORY       -1.431888e+04
# Non Factory        1.614289e+08
# Physical Delivery  4.238811e+08
# Traditional MSJ    5.271730e+07

# %% [markdown]
# # FILTER-2-Tier Factory, NTG (WPL)

# %%
c2=['=','N'] # List created with conditions for df['Txn Net Price Indicator']


filtered_df = df[(df['Corporate Bookings Flag'] == 'N') & (df['Bookings Adjustments Type']=='BOOKING') & (df['Txn Net Price Indicator'].isin(c2))] 

p12 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p12
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic        -2.914500e+02
# Non Factory       -3.602419e+06
# Physical Delivery -1.708401e+08
# Traditional MSJ   -7.338030e+04

# %% [markdown]
# # FILTER- 2-Tier Factory NTG Bookingsnet

# %%
filtered_df = df[(df['Corporate Bookings Flag'] == 'N') & (df['Bookings Adjustments Type']=='BOOKING') & (df['Txn Net Price Indicator']=='Y')] 

p13 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p13
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic        -6.265643e+04
# Non Factory       -8.039666e+05
# Physical Delivery -9.345785e+06
# Traditional MSJ   -1.123325e+06

# %% [markdown]
# # FILTER- 2-Tier Factory, Gross (WPL)

# %%
c2=['=','N'] # List created with conditions for df['Txn Net Price Indicator']


filtered_df = df[(df['Corporate Bookings Flag'] == 'N') & (df['Bookings Adjustments Type']==0) & (df['Txn Net Price Indicator'].isin(c2))] 

p14 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p14
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic         5.238074e+05
# Non Factory        5.349241e+06
# Physical Delivery  3.334675e+08
# Traditional MSJ    1.146803e+04

# %% [markdown]
# # FILTER-2-Tier NonFactory, Gross (WPL)

# %%
c1=['BOOKING',0] # list created with conditions for df['Bookings Adjustments Type']
c2=['=','N'] # List created with conditions for df['Txn Net Price Indicator']

filtered_df = df[(df['Corporate Bookings Flag'] == 'N') & (df['Bookings Adjustments Type'].isin(c1)) & (df['Txn Net Price Indicator'].isin(c2))] 

p15 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p15
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic         5.235159e+05
# Non Factory        1.746822e+06
# Physical Delivery  1.626274e+08
# Traditional MSJ   -6.191227e+04

# %% [markdown]
# # FILTER-2-Tier Factory & Non-Factory Gross (net price)

# %%
filtered_df = df[(df['Corporate Bookings Flag'] == 'N') & (df['Bookings Adjustments Type']==0) & (df['Txn Net Price Indicator']=='Y')] 

p16 = pd.pivot_table(filtered_df, 
                    columns=['Fiscal Quarter ID', 'Fiscal Period ID'], 
                    index='Business Model', 
                    values='Product Bookings Net', 
                    aggfunc=sum)
p16
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Electronic         6.793897e+06
# NON FACTORY       -1.431888e+04
# Non Factory        1.622328e+08
# Physical Delivery  4.332269e+08
# Traditional MSJ    5.384063e+07

# %%
p16.loc[['Physical Delivery','Traditional MSJ']] # pass 2D array for dataframe
# Out:
# Fiscal Quarter ID        2025Q2
# Fiscal Period ID         202504
# Business Model
# Physical Delivery  4.332269e+08
# Traditional MSJ    5.384063e+07

# %% [markdown]
# # Pending Tasks:
# # how to filter index or rows- to select values under 'Business Model'- use loc method
# # Fix the Non-Factory and NON FACTORY under 'Business Model'
# # Map the excel outputs with the script output and naming convention
# # Export to excel
