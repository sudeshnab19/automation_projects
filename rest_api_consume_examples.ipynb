# %%
import requests

# %%
server_url = "http://127.0.0.1:5000/"
endpoint = "weather/nyc"
complete_url = server_url + endpoint

# %%
complete_url
# Out:
# 'http://127.0.0.1:5000/weather/nyc'

# %%
response = requests.get(complete_url)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'CloudCover': 5,
#   'DewPoint': 23,
#   'EST': '1/1/2016',
#   'Events': 'null',
#   'Humidity': 52,
#   'PrecipitationIn': 0,
#   'Sea Level PressureIn': 30.03,
#   'Temperature': 38,
#   'VisibilityMiles': 10,
#   'WindDirDegrees': 281,
#   'WindSpeedMPH': 8.0},
#  {'CloudCover': 3,
#   'DewPoint': 18,
#   'EST': '1/2/2016',
#   'Events': 'null',
#   'Humidity': 46,
#   'PrecipitationIn': 0,
#   'Sea Level PressureIn': 30.02,
#   'Temperature': 36,
#   'VisibilityMiles': 10,
#   'WindDirDegrees': 275,
#   'WindSpeedMPH': 7.0},
#  {'CloudCover': 1,
#   'DewPoint': 21,
#   'EST': '1/3/2016',
#   'Events': 'null',
#   'Humidity': 47,
#   'PrecipitationIn': 0,
#   'Sea Level PressureIn': 29.86,
#   'Temperature': 40,
#   'VisibilityMiles': 10,
#   'WindDirDegrees': 277,
#   'WindSpeedMPH': 8.0},
#  {'CloudCover': 3,
#   'DewPoint': 9,
#   'EST': '1/4/2016',
#   'Events': 'null',
#   'Humidity': 44,
#   'PrecipitationIn': 0,
#   'Sea Level PressureIn': 30.05,
#   'Temperature': 25,
# ...
